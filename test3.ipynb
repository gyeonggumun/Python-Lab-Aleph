# %%
name = "한빛페이"    # str
count = 5            # int
rate = 0.1           # float
is_ok = True         # bool

print(name, count, rate, is_ok)
print(type(count), type(rate))
# Out:
# 한빛페이 5 0.1 True
# <class 'int'> <class 'float'>
