# %%
import requests

url = "http://localhost:5678/webhook-test/ced10dfe-0f09-4301-8aae-032798353e32"
payload = {"ip": "1.2.3.4", "level": 10, "rule": "5712"}
r = requests.post(url, json=payload)
print(r.status_code)   # 200
# Out:
# 200
